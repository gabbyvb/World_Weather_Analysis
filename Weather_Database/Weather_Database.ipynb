# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | leningradskiy
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | luganville
# Processing Record 6 of Set 1 | changde
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | esperance
# Processing Record 10 of Set 1 | astoria
# Processing Record 11 of Set 1 | guarapari
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | kungurtug
# Processing Record 15 of Set 1 | gobabis
# Processing Record 16 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | college
# Processing Record 19 of Set 1 | san cristobal
# Processing Record 20 of Set 1 | tibiri
# Processing Record 21 of Set 1 | prieska
# Processing Record 22 of Set 1 | bilibino
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 1 | arlit
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | kaitangata
# Processing Record 28 of Set 1 | luderitz
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 1 | belle fourche
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | saintes
# Processing Record 39 of Set 1 | vryburg
# Processing Record 40 of Set 1 | marsh harbour
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | pangnirtung
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | sumoto
# Processing Record 47 of Set 1 | krasnoarmeysk
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | mount pleasant
# Processing Record 50 of Set 1 | kulhudhuffushi
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | korla
# Processing Record 3 of Set 2 | lorengau
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | avarua
# Processing Record 8 of Set 2 | burica
# City not found. Skipping...
# Processing Record 9 of Set 2 | kahului
# Processing Record 10 of Set 2 | marienburg
# Processing Record 11 of Set 2 | chateauroux
# Processing Record 12 of Set 2 | narsaq
# Processing Record 13 of Set 2 | los llanos de aridane
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | mount gambier
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | mount isa
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | palaikastron
# Processing Record 20 of Set 2 | campoverde
# Processing Record 21 of Set 2 | inhambane
# Processing Record 22 of Set 2 | namibe
# Processing Record 23 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | roald
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | locri
# Processing Record 30 of Set 2 | cabra
# Processing Record 31 of Set 2 | kropotkin
# Processing Record 32 of Set 2 | gushikawa
# Processing Record 33 of Set 2 | saskylakh
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | ixtapa
# Processing Record 36 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 2 | aklavik
# Processing Record 38 of Set 2 | busselton
# Processing Record 39 of Set 2 | san juan de los lagos
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | bengkulu
# Processing Record 42 of Set 2 | kilkenny
# Processing Record 43 of Set 2 | gusau
# Processing Record 44 of Set 2 | alihe
# Processing Record 45 of Set 2 | tombouctou
# Processing Record 46 of Set 2 | topchikha
# Processing Record 47 of Set 2 | yerbogachen
# Processing Record 48 of Set 2 | hofn
# Processing Record 49 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 2 | sao felix do xingu
# Processing Record 1 of Set 3 | faya
# Processing Record 2 of Set 3 | kuryk
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | richards bay
# Processing Record 5 of Set 3 | port lincoln
# Processing Record 6 of Set 3 | ponta do sol
# Processing Record 7 of Set 3 | khatanga
# Processing Record 8 of Set 3 | komsomolskiy
# Processing Record 9 of Set 3 | gorontalo
# Processing Record 10 of Set 3 | berlevag
# Processing Record 11 of Set 3 | riverton
# Processing Record 12 of Set 3 | hueytown
# Processing Record 13 of Set 3 | bluff
# Processing Record 14 of Set 3 | vila franca do campo
# Processing Record 15 of Set 3 | hasaki
# Processing Record 16 of Set 3 | roros
# Processing Record 17 of Set 3 | srednekolymsk
# Processing Record 18 of Set 3 | puerto escondido
# Processing Record 19 of Set 3 | dyadkovskaya
# City not found. Skipping...
# Processing Record 20 of Set 3 | udachnyy
# Processing Record 21 of Set 3 | jalu
# Processing Record 22 of Set 3 | shimoda
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | paamiut
# Processing Record 25 of Set 3 | cedar city
# Processing Record 26 of Set 3 | quatre cocos
# Processing Record 27 of Set 3 | nome
# Processing Record 28 of Set 3 | marica
# Processing Record 29 of Set 3 | guerrero negro
# Processing Record 30 of Set 3 | tilichiki
# Processing Record 31 of Set 3 | mataura
# Processing Record 32 of Set 3 | veinticinco de mayo
# Processing Record 33 of Set 3 | qaanaaq
# Processing Record 34 of Set 3 | walvis bay
# Processing Record 35 of Set 3 | port augusta
# Processing Record 36 of Set 3 | chuy
# Processing Record 37 of Set 3 | asau
# Processing Record 38 of Set 3 | haines junction
# Processing Record 39 of Set 3 | kurilsk
# Processing Record 40 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 41 of Set 3 | santana do livramento
# Processing Record 42 of Set 3 | lena
# Processing Record 43 of Set 3 | dunedin
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | olafsvik
# Processing Record 46 of Set 3 | bandarbeyla
# Processing Record 47 of Set 3 | valdez
# Processing Record 48 of Set 3 | xichang
# Processing Record 49 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 3 | turukhansk
# Processing Record 1 of Set 4 | robertsport
# Processing Record 2 of Set 4 | dikson
# Processing Record 3 of Set 4 | sibolga
# Processing Record 4 of Set 4 | sorland
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | praia da vitoria
# Processing Record 7 of Set 4 | coquimbo
# Processing Record 8 of Set 4 | codrington
# Processing Record 9 of Set 4 | bundaberg
# Processing Record 10 of Set 4 | puerto ayora
# Processing Record 11 of Set 4 | xiangdong
# City not found. Skipping...
# Processing Record 12 of Set 4 | pevek
# Processing Record 13 of Set 4 | severo-kurilsk
# Processing Record 14 of Set 4 | cayenne
# Processing Record 15 of Set 4 | cabo san lucas
# Processing Record 16 of Set 4 | sampit
# Processing Record 17 of Set 4 | takoradi
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | sitka
# Processing Record 20 of Set 4 | nongan
# Processing Record 21 of Set 4 | norman wells
# Processing Record 22 of Set 4 | pitimbu
# Processing Record 23 of Set 4 | hailar
# Processing Record 24 of Set 4 | san quintin
# Processing Record 25 of Set 4 | kendari
# Processing Record 26 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 4 | ilulissat
# Processing Record 28 of Set 4 | havoysund
# Processing Record 29 of Set 4 | rio grande
# Processing Record 30 of Set 4 | portland
# Processing Record 31 of Set 4 | laguna
# Processing Record 32 of Set 4 | faanui
# Processing Record 33 of Set 4 | ulladulla
# Processing Record 34 of Set 4 | svetlogorsk
# Processing Record 35 of Set 4 | nelson bay
# Processing Record 36 of Set 4 | afanasyevo
# City not found. Skipping...
# Processing Record 37 of Set 4 | isangel
# Processing Record 38 of Set 4 | ayagoz
# Processing Record 39 of Set 4 | birin
# Processing Record 40 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 4 | linxia
# Processing Record 42 of Set 4 | tuktoyaktuk
# Processing Record 43 of Set 4 | dezhou
# Processing Record 44 of Set 4 | vestmanna
# Processing Record 45 of Set 4 | orthez
# Processing Record 46 of Set 4 | fairbanks
# Processing Record 47 of Set 4 | plettenberg bay
# Processing Record 48 of Set 4 | ahumada
# City not found. Skipping...
# Processing Record 49 of Set 4 | wilmington
# Processing Record 50 of Set 4 | coihaique
# Processing Record 1 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 5 | kingori
# Processing Record 3 of Set 5 | pisco
# Processing Record 4 of Set 5 | wanning
# Processing Record 5 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 5 | muisne
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | victoria
# Processing Record 9 of Set 5 | ciudad bolivar
# Processing Record 10 of Set 5 | don sak
# Processing Record 11 of Set 5 | wenling
# Processing Record 12 of Set 5 | sao joao da barra
# Processing Record 13 of Set 5 | kichera
# Processing Record 14 of Set 5 | xingyi
# Processing Record 15 of Set 5 | yokadouma
# Processing Record 16 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 17 of Set 5 | loiza
# Processing Record 18 of Set 5 | caravelas
# Processing Record 19 of Set 5 | vardo
# Processing Record 20 of Set 5 | tornio
# Processing Record 21 of Set 5 | itapua poty
# City not found. Skipping...
# Processing Record 22 of Set 5 | aripuana
# Processing Record 23 of Set 5 | manuk mangkaw
# Processing Record 24 of Set 5 | fare
# Processing Record 25 of Set 5 | yemtsa
# Processing Record 26 of Set 5 | dingle
# Processing Record 27 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 5 | porto novo
# Processing Record 29 of Set 5 | san pedro de uraba
# Processing Record 30 of Set 5 | sorsk
# Processing Record 31 of Set 5 | cururupu
# Processing Record 32 of Set 5 | yumen
# Processing Record 33 of Set 5 | santa cruz de la palma
# Processing Record 34 of Set 5 | trabzon
# Processing Record 35 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 5 | deputatskiy
# Processing Record 37 of Set 5 | comarapa
# Processing Record 38 of Set 5 | tiksi
# Processing Record 39 of Set 5 | valenca do piaui
# Processing Record 40 of Set 5 | cape town
# Processing Record 41 of Set 5 | kijang
# Processing Record 42 of Set 5 | mangai
# Processing Record 43 of Set 5 | meulaboh
# Processing Record 44 of Set 5 | central point
# Processing Record 45 of Set 5 | vila velha
# Processing Record 46 of Set 5 | upernavik
# Processing Record 47 of Set 5 | barbate
# Processing Record 48 of Set 5 | vestmannaeyjar
# Processing Record 49 of Set 5 | cidreira
# Processing Record 50 of Set 5 | biankouma
# Processing Record 1 of Set 6 | manhattan
# Processing Record 2 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 6 | warri
# Processing Record 5 of Set 6 | vanimo
# Processing Record 6 of Set 6 | tuatapere
# Processing Record 7 of Set 6 | tomatlan
# Processing Record 8 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 6 | kathmandu
# Processing Record 11 of Set 6 | zhigansk
# Processing Record 12 of Set 6 | lavrentiya
# Processing Record 13 of Set 6 | mardin
# Processing Record 14 of Set 6 | that phanom
# Processing Record 15 of Set 6 | nanortalik
# Processing Record 16 of Set 6 | barinas
# Processing Record 17 of Set 6 | galveston
# Processing Record 18 of Set 6 | ust-nera
# Processing Record 19 of Set 6 | biak
# Processing Record 20 of Set 6 | georgetown
# Processing Record 21 of Set 6 | mikhaylovka
# Processing Record 22 of Set 6 | constitucion
# Processing Record 23 of Set 6 | bay roberts
# Processing Record 24 of Set 6 | tiznit
# Processing Record 25 of Set 6 | ruwi
# Processing Record 26 of Set 6 | natal
# Processing Record 27 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 6 | umm kaddadah
# Processing Record 29 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 6 | bairnsdale
# Processing Record 31 of Set 6 | adamantina
# Processing Record 32 of Set 6 | mul
# Processing Record 33 of Set 6 | la paz
# Processing Record 34 of Set 6 | samarai
# Processing Record 35 of Set 6 | matara
# Processing Record 36 of Set 6 | igrim
# Processing Record 37 of Set 6 | yerazgavors
# Processing Record 38 of Set 6 | conde
# Processing Record 39 of Set 6 | carupano
# Processing Record 40 of Set 6 | dera din panah
# City not found. Skipping...
# Processing Record 41 of Set 6 | broome
# Processing Record 42 of Set 6 | sioux lookout
# Processing Record 43 of Set 6 | san policarpo
# Processing Record 44 of Set 6 | bhatkal
# Processing Record 45 of Set 6 | allapalli
# Processing Record 46 of Set 6 | broken hill
# Processing Record 47 of Set 6 | fukue
# Processing Record 48 of Set 6 | makakilo city
# Processing Record 49 of Set 6 | flinders
# Processing Record 50 of Set 6 | touros
# Processing Record 1 of Set 7 | kandalaksha
# Processing Record 2 of Set 7 | charlestown
# Processing Record 3 of Set 7 | cairns
# Processing Record 4 of Set 7 | lom sak
# Processing Record 5 of Set 7 | severnyy
# Processing Record 6 of Set 7 | fortuna
# Processing Record 7 of Set 7 | ust-kuyga
# Processing Record 8 of Set 7 | virden
# Processing Record 9 of Set 7 | hervey bay
# Processing Record 10 of Set 7 | sao jose da coroa grande
# Processing Record 11 of Set 7 | el balyana
# City not found. Skipping...
# Processing Record 12 of Set 7 | san felipe
# Processing Record 13 of Set 7 | pychas
# Processing Record 14 of Set 7 | klaksvik
# Processing Record 15 of Set 7 | surt
# Processing Record 16 of Set 7 | puerto gaitan
# Processing Record 17 of Set 7 | hobart
# Processing Record 18 of Set 7 | erenhot
# Processing Record 19 of Set 7 | pionerskiy
# Processing Record 20 of Set 7 | pacifica
# Processing Record 21 of Set 7 | kavieng
# Processing Record 22 of Set 7 | russell
# Processing Record 23 of Set 7 | kamina
# Processing Record 24 of Set 7 | ruidoso
# Processing Record 25 of Set 7 | ilembula
# Processing Record 26 of Set 7 | yeppoon
# Processing Record 27 of Set 7 | sinaloa
# Processing Record 28 of Set 7 | oktyabrskoye
# Processing Record 29 of Set 7 | west bay
# Processing Record 30 of Set 7 | atambua
# Processing Record 31 of Set 7 | ayios matthaios
# City not found. Skipping...
# Processing Record 32 of Set 7 | tadine
# Processing Record 33 of Set 7 | longyearbyen
# Processing Record 34 of Set 7 | ancud
# Processing Record 35 of Set 7 | blagoyevo
# Processing Record 36 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 7 | dalby
# Processing Record 38 of Set 7 | patrocinio
# Processing Record 39 of Set 7 | urubamba
# Processing Record 40 of Set 7 | rundu
# Processing Record 41 of Set 7 | kencong
# Processing Record 42 of Set 7 | tura
# Processing Record 43 of Set 7 | port hawkesbury
# Processing Record 44 of Set 7 | tasiilaq
# Processing Record 45 of Set 7 | abrau-dyurso
# Processing Record 46 of Set 7 | cherskiy
# Processing Record 47 of Set 7 | gouyave
# Processing Record 48 of Set 7 | yulara
# Processing Record 49 of Set 7 | omboue
# Processing Record 50 of Set 7 | boguchany
# Processing Record 1 of Set 8 | sao gabriel da cachoeira
# Processing Record 2 of Set 8 | sevlievo
# Processing Record 3 of Set 8 | sangar
# Processing Record 4 of Set 8 | escalerillas
# Processing Record 5 of Set 8 | havre-saint-pierre
# Processing Record 6 of Set 8 | maningrida
# Processing Record 7 of Set 8 | port keats
# Processing Record 8 of Set 8 | nioro
# Processing Record 9 of Set 8 | kimbe
# Processing Record 10 of Set 8 | aljezur
# Processing Record 11 of Set 8 | tezu
# Processing Record 12 of Set 8 | ohara
# Processing Record 13 of Set 8 | oussouye
# Processing Record 14 of Set 8 | ribeira grande
# Processing Record 15 of Set 8 | diebougou
# Processing Record 16 of Set 8 | torbay
# Processing Record 17 of Set 8 | akureyri
# Processing Record 18 of Set 8 | smithers
# Processing Record 19 of Set 8 | beringovskiy
# Processing Record 20 of Set 8 | poum
# Processing Record 21 of Set 8 | malya
# Processing Record 22 of Set 8 | kavaratti
# Processing Record 23 of Set 8 | qaqortoq
# Processing Record 24 of Set 8 | tjome
# Processing Record 25 of Set 8 | babstovo
# Processing Record 26 of Set 8 | iquitos
# Processing Record 27 of Set 8 | batagay
# Processing Record 28 of Set 8 | luyang
# Processing Record 29 of Set 8 | jesup
# Processing Record 30 of Set 8 | port blair
# Processing Record 31 of Set 8 | gelgaudiskis
# Processing Record 32 of Set 8 | zabol
# Processing Record 33 of Set 8 | provideniya
# Processing Record 34 of Set 8 | nowy dwor mazowiecki
# Processing Record 35 of Set 8 | biltine
# Processing Record 36 of Set 8 | oxford
# Processing Record 37 of Set 8 | alekseyevka
# Processing Record 38 of Set 8 | havre
# Processing Record 39 of Set 8 | karpathos
# Processing Record 40 of Set 8 | vostok
# Processing Record 41 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 42 of Set 8 | sakaiminato
# Processing Record 43 of Set 8 | tambura
# Processing Record 44 of Set 8 | rincon
# Processing Record 45 of Set 8 | yatou
# Processing Record 46 of Set 8 | aizkraukle
# Processing Record 47 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 8 | cassilandia
# Processing Record 49 of Set 8 | moses lake
# Processing Record 50 of Set 8 | kibala
# Processing Record 1 of Set 9 | adrar
# Processing Record 2 of Set 9 | katherine
# Processing Record 3 of Set 9 | maturin
# Processing Record 4 of Set 9 | mananara
# Processing Record 5 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 6 of Set 9 | san vicente
# Processing Record 7 of Set 9 | jalingo
# Processing Record 8 of Set 9 | bam
# Processing Record 9 of Set 9 | emba
# Processing Record 10 of Set 9 | atar
# Processing Record 11 of Set 9 | sao filipe
# Processing Record 12 of Set 9 | oruro
# Processing Record 13 of Set 9 | saint quentin
# City not found. Skipping...
# Processing Record 14 of Set 9 | toamasina
# Processing Record 15 of Set 9 | sinyavino
# Processing Record 16 of Set 9 | owando
# Processing Record 17 of Set 9 | arman
# Processing Record 18 of Set 9 | latung
# Processing Record 19 of Set 9 | padang
# Processing Record 20 of Set 9 | talara
# Processing Record 21 of Set 9 | ignacio zaragoza
# Processing Record 22 of Set 9 | sete
# Processing Record 23 of Set 9 | peniche
# Processing Record 24 of Set 9 | brylivka
# Processing Record 25 of Set 9 | orlik
# Processing Record 26 of Set 9 | westport
# Processing Record 27 of Set 9 | gemena
# Processing Record 28 of Set 9 | falam
# Processing Record 29 of Set 9 | kurtalan
# Processing Record 30 of Set 9 | severnoye
# Processing Record 31 of Set 9 | bismarck
# Processing Record 32 of Set 9 | nizhneudinsk
# Processing Record 33 of Set 9 | souillac
# Processing Record 34 of Set 9 | xinxiang
# Processing Record 35 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 36 of Set 9 | lima
# Processing Record 37 of Set 9 | kloulklubed
# Processing Record 38 of Set 9 | valdivia
# Processing Record 39 of Set 9 | swinoujscie
# Processing Record 40 of Set 9 | moindou
# Processing Record 41 of Set 9 | kandrian
# Processing Record 42 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 9 | necochea
# Processing Record 44 of Set 9 | san rafael
# Processing Record 45 of Set 9 | mandera
# Processing Record 46 of Set 9 | muros
# Processing Record 47 of Set 9 | mandiana
# Processing Record 48 of Set 9 | nsanje
# Processing Record 49 of Set 9 | prince rupert
# Processing Record 50 of Set 9 | leh
# Processing Record 1 of Set 10 | whitehorse
# Processing Record 2 of Set 10 | eskisehir
# Processing Record 3 of Set 10 | olutanga
# Processing Record 4 of Set 10 | verkhnyaya inta
# Processing Record 5 of Set 10 | caruray
# Processing Record 6 of Set 10 | presidencia roque saenz pena
# Processing Record 7 of Set 10 | romanovka
# Processing Record 8 of Set 10 | tazovskiy
# Processing Record 9 of Set 10 | akom
# Processing Record 10 of Set 10 | ketchenery
# City not found. Skipping...
# Processing Record 11 of Set 10 | gornopravdinsk
# Processing Record 12 of Set 10 | chicama
# Processing Record 13 of Set 10 | talnakh
# Processing Record 14 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 10 | santa fe
# Processing Record 16 of Set 10 | northam
# Processing Record 17 of Set 10 | rocha
# Processing Record 18 of Set 10 | mikun
# Processing Record 19 of Set 10 | ahipara
# Processing Record 20 of Set 10 | magadan
# Processing Record 21 of Set 10 | huarmey
# Processing Record 22 of Set 10 | waterford
# Processing Record 23 of Set 10 | balakhninskiy
# Processing Record 24 of Set 10 | huaihua
# Processing Record 25 of Set 10 | salalah
# Processing Record 26 of Set 10 | nuuk
# Processing Record 27 of Set 10 | la reforma
# Processing Record 28 of Set 10 | khani
# Processing Record 29 of Set 10 | buraydah
# Processing Record 30 of Set 10 | letterkenny
# Processing Record 31 of Set 10 | lagoa
# Processing Record 32 of Set 10 | douglas
# Processing Record 33 of Set 10 | llano de piedra
# Processing Record 34 of Set 10 | whyalla
# Processing Record 35 of Set 10 | chimbote
# Processing Record 36 of Set 10 | fort-shevchenko
# Processing Record 37 of Set 10 | lahad datu
# Processing Record 38 of Set 10 | grandview
# Processing Record 39 of Set 10 | lompoc
# Processing Record 40 of Set 10 | pahrump
# Processing Record 41 of Set 10 | micheweni
# Processing Record 42 of Set 10 | nobeoka
# Processing Record 43 of Set 10 | port-gentil
# Processing Record 44 of Set 10 | norilsk
# Processing Record 45 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 10 | treinta y tres
# Processing Record 47 of Set 10 | vakhrushev
# Processing Record 48 of Set 10 | plerin
# Processing Record 49 of Set 10 | ningan
# City not found. Skipping...
# Processing Record 50 of Set 10 | praia
# Processing Record 1 of Set 11 | tarko-sale
# Processing Record 2 of Set 11 | campbell river
# Processing Record 3 of Set 11 | port antonio
# Processing Record 4 of Set 11 | smidovich
# Processing Record 5 of Set 11 | lianran
# Processing Record 6 of Set 11 | uarini
# Processing Record 7 of Set 11 | renukut
# Processing Record 8 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 11 | saint-michel-des-saints
# Processing Record 10 of Set 11 | ostrovnoy
# Processing Record 11 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 12 of Set 11 | chhibramau
# Processing Record 13 of Set 11 | karratha
# Processing Record 14 of Set 11 | mehamn
# Processing Record 15 of Set 11 | bubaque
# Processing Record 16 of Set 11 | erie
# Processing Record 17 of Set 11 | santa maria
# Processing Record 18 of Set 11 | chippewa falls
# Processing Record 19 of Set 11 | tual
# Processing Record 20 of Set 11 | jupiter
# Processing Record 21 of Set 11 | valente
# Processing Record 22 of Set 11 | bathsheba
# Processing Record 23 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 24 of Set 11 | dryden
# Processing Record 25 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 26 of Set 11 | manati
# Processing Record 27 of Set 11 | york
# Processing Record 28 of Set 11 | hornepayne
# Processing Record 29 of Set 11 | ubinskoye
# Processing Record 30 of Set 11 | marsa matruh
# Processing Record 31 of Set 11 | brae
# Processing Record 32 of Set 11 | sabang
# Processing Record 33 of Set 11 | dobroye
# Processing Record 34 of Set 11 | zabid
# Processing Record 35 of Set 11 | kattivakkam
# Processing Record 36 of Set 11 | azuaga
# Processing Record 37 of Set 11 | sur
# Processing Record 38 of Set 11 | zemio
# Processing Record 39 of Set 11 | butterworth
# Processing Record 40 of Set 11 | kisangani
# Processing Record 41 of Set 11 | poya
# Processing Record 42 of Set 11 | tatarbunary
# Processing Record 43 of Set 11 | egersund
# Processing Record 44 of Set 11 | orotukan
# Processing Record 45 of Set 11 | khilok
# Processing Record 46 of Set 11 | pandan
# Processing Record 47 of Set 11 | luwingu
# Processing Record 48 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 49 of Set 11 | san juan
# Processing Record 50 of Set 11 | maidenhead
# Processing Record 1 of Set 12 | bull savanna
# Processing Record 2 of Set 12 | leo
# Processing Record 3 of Set 12 | marsabit
# Processing Record 4 of Set 12 | kalmunai
# Processing Record 5 of Set 12 | acapulco
# Processing Record 6 of Set 12 | fort stewart
# Processing Record 7 of Set 12 | buduran
# Processing Record 8 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 9 of Set 12 | leshukonskoye
# Processing Record 10 of Set 12 | ketchikan
# Processing Record 11 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 12 | khandbari
# Processing Record 13 of Set 12 | shiraz
# Processing Record 14 of Set 12 | mbaiki
# Processing Record 15 of Set 12 | antalaha
# Processing Record 16 of Set 12 | kuhestan
# City not found. Skipping...
# Processing Record 17 of Set 12 | santiago del estero
# Processing Record 18 of Set 12 | dharchula
# Processing Record 19 of Set 12 | cap malheureux
# Processing Record 20 of Set 12 | avera
# Processing Record 21 of Set 12 | dicabisagan
# Processing Record 22 of Set 12 | baracoa
# Processing Record 23 of Set 12 | sibi
# Processing Record 24 of Set 12 | jibuti
# Processing Record 25 of Set 12 | kruisfontein
# Processing Record 26 of Set 12 | torrington
# Processing Record 27 of Set 12 | anadyr
# Processing Record 28 of Set 12 | santa rosa
# Processing Record 29 of Set 12 | sayula
# Processing Record 30 of Set 12 | maryville
# Processing Record 31 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 12 | sulangan
# Processing Record 33 of Set 12 | pavlovsk
# Processing Record 34 of Set 12 | lillooet
# Processing Record 35 of Set 12 | tomohon
# Processing Record 36 of Set 12 | husavik
# Processing Record 37 of Set 12 | alofi
# Processing Record 38 of Set 12 | san lawrenz
# Processing Record 39 of Set 12 | sokoni
# Processing Record 40 of Set 12 | bulgan
# Processing Record 41 of Set 12 | kitsuki
# Processing Record 42 of Set 12 | ivanava
# Processing Record 43 of Set 12 | champerico
# Processing Record 44 of Set 12 | doha
# Processing Record 45 of Set 12 | hamilton
# Processing Record 46 of Set 12 | dulce nombre de culmi
# Processing Record 47 of Set 12 | zapolyarnyy
# Processing Record 48 of Set 12 | juruti
# Processing Record 49 of Set 12 | atherton
# Processing Record 50 of Set 12 | tacuarembo
# Processing Record 1 of Set 13 | nong chik
# Processing Record 2 of Set 13 | quesnel
# Processing Record 3 of Set 13 | bosaso
# Processing Record 4 of Set 13 | shieli
# Processing Record 5 of Set 13 | goderich
# Processing Record 6 of Set 13 | diplo
# Processing Record 7 of Set 13 | olga
# Processing Record 8 of Set 13 | ulze
# City not found. Skipping...
# Processing Record 9 of Set 13 | flin flon
# Processing Record 10 of Set 13 | phan thiet
# Processing Record 11 of Set 13 | tocopilla
# Processing Record 12 of Set 13 | kollam
# Processing Record 13 of Set 13 | verkh-usugli
# Processing Record 14 of Set 13 | port hardy
# Processing Record 15 of Set 13 | kuminskiy
# Processing Record 16 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 17 of Set 13 | safford
# Processing Record 18 of Set 13 | aykhal
# Processing Record 19 of Set 13 | mackay
# Processing Record 20 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 13 | glubokiy
# Processing Record 22 of Set 13 | sesheke
# Processing Record 23 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 13 | leeton
# Processing Record 25 of Set 13 | aksu
# Processing Record 26 of Set 13 | payson
# Processing Record 27 of Set 13 | sinnamary
# Processing Record 28 of Set 13 | matagami
# Processing Record 29 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 30 of Set 13 | mujiayingzi
# Processing Record 31 of Set 13 | tretten
# Processing Record 32 of Set 13 | svirstroy
# Processing Record 33 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 34 of Set 13 | zhanaozen
# Processing Record 35 of Set 13 | tshikapa
# Processing Record 36 of Set 13 | yanam
# Processing Record 37 of Set 13 | gasa
# Processing Record 38 of Set 13 | ballarat
# Processing Record 39 of Set 13 | newport
# Processing Record 40 of Set 13 | inirida
# Processing Record 41 of Set 13 | andrychow
# Processing Record 42 of Set 13 | hambantota
# Processing Record 43 of Set 13 | bahia honda
# Processing Record 44 of Set 13 | upington
# Processing Record 45 of Set 13 | santa cruz de tenerife
# Processing Record 46 of Set 13 | buerarema
# Processing Record 47 of Set 13 | tamiahua
# Processing Record 48 of Set 13 | taicheng
# Processing Record 49 of Set 13 | chapais
# Processing Record 50 of Set 13 | tommot
# Processing Record 1 of Set 14 | mackenzie
# Processing Record 2 of Set 14 | glenwood springs
# Processing Record 3 of Set 14 | novo aripuana
# Processing Record 4 of Set 14 | reo
# Processing Record 5 of Set 14 | hammerfest
# Processing Record 6 of Set 14 | shingu
# Processing Record 7 of Set 14 | cervo
# Processing Record 8 of Set 14 | soavinandriana
# Processing Record 9 of Set 14 | hobyo
# Processing Record 10 of Set 14 | loding
# Processing Record 11 of Set 14 | nangomba
# Processing Record 12 of Set 14 | verkhoyansk
# Processing Record 13 of Set 14 | ilabaya
# Processing Record 14 of Set 14 | nkowakowa
# Processing Record 15 of Set 14 | mufulira
# Processing Record 16 of Set 14 | loikaw
# Processing Record 17 of Set 14 | azrow
# City not found. Skipping...
# Processing Record 18 of Set 14 | north bend
# Processing Record 19 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 20 of Set 14 | isla vista
# Processing Record 21 of Set 14 | kernersville
# Processing Record 22 of Set 14 | chifeng
# Processing Record 23 of Set 14 | vastervik
# City not found. Skipping...
# Processing Record 24 of Set 14 | toguchin
# Processing Record 25 of Set 14 | pemba
# Processing Record 26 of Set 14 | jambi
# Processing Record 27 of Set 14 | namatanai
# Processing Record 28 of Set 14 | saint-pierre
# Processing Record 29 of Set 14 | bella vista
# Processing Record 30 of Set 14 | kainantu
# Processing Record 31 of Set 14 | camacha
# Processing Record 32 of Set 14 | galesong
# Processing Record 33 of Set 14 | am timan
# Processing Record 34 of Set 14 | sasolburg
# Processing Record 35 of Set 14 | penal
# Processing Record 36 of Set 14 | saint-georges
# Processing Record 37 of Set 14 | la ronge
# Processing Record 38 of Set 14 | garissa
# Processing Record 39 of Set 14 | novaya ladoga
# Processing Record 40 of Set 14 | kuna
# Processing Record 41 of Set 14 | kaeo
# Processing Record 42 of Set 14 | dofteana
# Processing Record 43 of Set 14 | buin
# Processing Record 44 of Set 14 | asyut
# Processing Record 45 of Set 14 | adzope
# Processing Record 46 of Set 14 | birao
# Processing Record 47 of Set 14 | sambava
# Processing Record 48 of Set 14 | pochutla
# Processing Record 49 of Set 14 | toledo
# Processing Record 50 of Set 14 | yakeshi
# Processing Record 1 of Set 15 | tabou
# Processing Record 2 of Set 15 | ocos
# Processing Record 3 of Set 15 | muncar
# Processing Record 4 of Set 15 | media luna
# Processing Record 5 of Set 15 | villamontes
# Processing Record 6 of Set 15 | ashland
# Processing Record 7 of Set 15 | kargopol
# Processing Record 8 of Set 15 | itarema
# Processing Record 9 of Set 15 | winsum
# Processing Record 10 of Set 15 | turinsk
# Processing Record 11 of Set 15 | adre
# Processing Record 12 of Set 15 | murud
# Processing Record 13 of Set 15 | viedma
# Processing Record 14 of Set 15 | gribanovskiy
# Processing Record 15 of Set 15 | macheng
# Processing Record 16 of Set 15 | pulgaon
# Processing Record 17 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 15 | panaba
# Processing Record 19 of Set 15 | shiyan
# Processing Record 20 of Set 15 | rockland
# Processing Record 21 of Set 15 | thunder bay
# Processing Record 22 of Set 15 | qeshm
# Processing Record 23 of Set 15 | ratnagiri
# Processing Record 24 of Set 15 | moose factory
# Processing Record 25 of Set 15 | cabedelo
# Processing Record 26 of Set 15 | merke
# Processing Record 27 of Set 15 | nara
# Processing Record 28 of Set 15 | teguldet
# Processing Record 29 of Set 15 | sindand
# City not found. Skipping...
# Processing Record 30 of Set 15 | zlobin
# Processing Record 31 of Set 15 | usagara
# Processing Record 32 of Set 15 | ibra
# Processing Record 33 of Set 15 | nhulunbuy
# Processing Record 34 of Set 15 | pio xii
# Processing Record 35 of Set 15 | napier
# Processing Record 36 of Set 15 | san isidro
# Processing Record 37 of Set 15 | sechura
# Processing Record 38 of Set 15 | la orilla
# Processing Record 39 of Set 15 | tecolutilla
# Processing Record 40 of Set 15 | tlahualilo
# City not found. Skipping...
# Processing Record 41 of Set 15 | baloda bazar
# Processing Record 42 of Set 15 | kasongo-lunda
# Processing Record 43 of Set 15 | sompeta
# Processing Record 44 of Set 15 | tandil
# Processing Record 45 of Set 15 | tigzirt
# Processing Record 46 of Set 15 | griffith
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 681

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Leningradskiy      RU  69.3833  178.4167      9.14        95         100
# 1       Hithadhoo      MV  -0.6000   73.0833     81.25        77          63
# 2  Saint-Philippe      RE -21.3585   55.7679     73.47        85          43
# 3      Luganville      VU -15.5333  167.1667     79.39        83          48
# 4         Changde      CN  29.0464  111.6783     53.51        66           2
# 5         Ushuaia      AR -54.8000  -68.3000     33.46        80          75
# 6           Kapaa      US  22.0752 -159.3190     80.58        76          20
# 7       Esperance      AU -33.8667  121.9000     67.84        35         100
# 8         Astoria      US  46.1879 -123.8313     57.90        73          90
# 9       Guarapari      BR -20.6667  -40.4975     84.09        86          68
#
#    Wind Speed Current Description
# 0        6.85     overcast clouds
# 1       14.29       broken clouds
# 2       15.99    scattered clouds
# 3        6.98    scattered clouds
# 4        3.00           clear sky
# 5       34.52                snow
# 6        3.00          few clouds
# 7       24.32     overcast clouds
# 8        3.00     overcast clouds
# 9       12.24       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
